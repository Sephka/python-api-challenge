# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities
# Out:
# ['general salgado',
#  'grindavik',
#  'thompson',
#  'chuy',
#  'buala',
#  'nikolskoye',
#  'hobart',
#  'yulara',
#  'vaitupu',
#  'manaus',
#  'svetlaya',
#  'tuktoyaktuk',
#  'kaitangata',
#  'ambilobe',
#  'busselton',
#  'albany',
#  'hermanus',
#  'teknaf',
#  'tottori',
#  'laguna',
#  'sorgun',
#  'cabo san lucas',
#  'haines junction',
#  'port hedland',
#  'leningradskiy',
#  'barrow',
#  'miranda',
#  'atuona',
#  'ushuaia',
#  'kapaa',
#  'longyearbyen',
#  'aporawan',
#  'upernavik',
#  'port alfred',
#  'puerto ayacucho',
#  'sentyabrskiy',
#  'belushya guba',
#  'starozhilovo',
#  'provideniya',
#  'okhotsk',
#  'grand river south east',
#  'punta arenas',
#  'vicuna',
#  'tuatapere',
#  'new norfolk',
#  'lompoc',
#  'kabare',
#  'constitucion',
#  'zhigansk',
#  'vaini',
#  'comodoro rivadavia',
#  'illoqqortoormiut',
#  'ust-tsilma',
#  'genhe',
#  'warqla',
#  'borovskoy',
#  'rungata',
#  'yarke pole',
#  'astana',
#  'yellowknife',
#  'east london',
#  'myre',
#  'waitati',
#  'meulaboh',
#  'saint anthony',
#  'tynda',
#  'mutsamudu',
#  'chokurdakh',
#  'bluff',
#  'palabuhanratu',
#  'port elizabeth',
#  'mwaya',
#  'geraldton',
#  'narsaq',
#  'arraial do cabo',
#  'tessalit',
#  'butaritari',
#  'udankudi',
#  'cockburn town',
#  'huaidian',
#  'athabasca',
#  'carnarvon',
#  'rikitea',
#  'egvekinot',
#  'anchorage',
#  'caravelas',
#  'port blair',
#  'islahiye',
#  'nizhneyansk',
#  'salalah',
#  'dhidhdhoo',
#  'tinskoy',
#  'nikki',
#  'belmonte',
#  'koutiala',
#  'port-gentil',
#  'barentsburg',
#  'klaeng',
#  'hami',
#  'sao filipe',
#  'batticaloa',
#  'iranshahr',
#  'bambous virieux',
#  'san cristobal',
#  'bintulu',
#  'vestmannaeyjar',
#  'puerto ayora',
#  'labuhan',
#  'taolanaro',
#  'najran',
#  'dikson',
#  'sao sebastiao',
#  'santa rosa de aguan',
#  'burica',
#  'avarua',
#  'qaanaaq',
#  'mataura',
#  'torbay',
#  'davila',
#  'khatanga',
#  'port lincoln',
#  'manzil kamil',
#  'bethel',
#  'mar del plata',
#  'ponta do sol',
#  'charters towers',
#  'jamestown',
#  'georgetown',
#  'castro',
#  'hilo',
#  'abu dhabi',
#  'bredasdorp',
#  'cape town',
#  'ilulissat',
#  'saskylakh',
#  'korla',
#  'sioux lookout',
#  'oranjemund',
#  'ongandjera',
#  'port hardy',
#  'ancud',
#  'madaoua',
#  'cherskiy',
#  'talnakh',
#  'blackford',
#  'soanierana ivongo',
#  'saleaula',
#  'coihaique',
#  'maniitsoq',
#  'houma',
#  'puerto suarez',
#  'sinnamary',
#  'kodiak',
#  'khyriv',
#  'sulangan',
#  'tiksi',
#  'dutlwe',
#  'faanui',
#  'inirida',
#  'tautira',
#  'rolim de moura',
#  'mahebourg',
#  'bengkulu',
#  'tasiilaq',
#  'ahipara',
#  'erzin',
#  'algiers',
#  'sosnovo-ozerskoye',
#  'baker city',
#  'cam ranh',
#  'novopokrovka',
#  'vao',
#  'stornoway',
#  'pahrump',
#  'denau',
#  'hithadhoo',
#  'quatre cocos',
#  'mys shmidta',
#  'noumea',
#  'husavik',
#  'poya',
#  'kawalu',
#  'hualmay',
#  'dongying',
#  'havoysund',
#  'pisco',
#  'upornaya',
#  'magdeburg',
#  'wichian buri',
#  'nanortalik',
#  'puri',
#  'ngunguru',
#  'lebu',
#  'lagoa',
#  'tiarei',
#  'esperance',
#  'tsihombe',
#  'pevek',
#  'katsuura',
#  'cayenne',
#  'attawapiskat',
#  'kahului',
#  'shenjiamen',
#  'miandrivazo',
#  'camoapa',
#  'nakhon thai',
#  'heishan',
#  'norman wells',
#  'andenes',
#  'cidreira',
#  'guaratinga',
#  'hofn',
#  'vila velha',
#  'dingle',
#  'coquimbo',
#  'yarada',
#  'gold coast',
#  'gamba',
#  'jumla',
#  'acapulco',
#  'atar',
#  'mahibadhoo',
#  'port macquarie',
#  'glendive',
#  'wapi pathum',
#  'sept-iles',
#  'dalbandin',
#  'tagpangi',
#  'pangnirtung',
#  'saint-joseph',
#  'abha',
#  'saint-philippe',
#  'lisakovsk',
#  'vila franca do campo',
#  'vincennes',
#  'dwarka',
#  'victoria',
#  'saint george',
#  'zhemchuzhnyy',
#  'hovd',
#  'takoradi',
#  'xinqing',
#  'suluq',
#  'sistranda',
#  'vanimo',
#  'maralal',
#  'brae',
#  'tondano',
#  'beloha',
#  'tutoia',
#  'sangar',
#  'chicama',
#  'karratha',
#  'eenhana',
#  'te anau',
#  'matay',
#  'sao miguel do araguaia',
#  'puerto del rosario',
#  'ambon',
#  'likasi',
#  'cururupu',
#  'luderitz',
#  'toamasina',
#  'samusu',
#  'inongo',
#  'arman',
#  'hamilton',
#  'santa rosa',
#  'utiroa',
#  'berlevag',
#  'myitkyina',
#  'shwebo',
#  'nelson bay',
#  'doctor pedro p. pena',
#  'kamaishi',
#  'matara',
#  'deputatskiy',
#  'aykino',
#  'hazorasp',
#  'upata',
#  'moscow',
#  'pimentel',
#  'le port',
#  'lavrentiya',
#  'naze',
#  'ribeira grande',
#  'raudeberg',
#  'derzhavinsk',
#  'usinsk',
#  'goure',
#  'hvolsvollur',
#  'zaraza',
#  'mount isa',
#  'ketchikan',
#  'koroni',
#  'praia da vitoria',
#  'qasigiannguit',
#  'neftcala',
#  'lorengau',
#  'sampit',
#  'bathsheba',
#  'viligili',
#  'porto novo',
#  'ebolowa',
#  'moose factory',
#  'kavieng',
#  'semey',
#  'kirakira',
#  'warrington',
#  'atbasar',
#  'toliary',
#  'bundaberg',
#  'gulf gate estates',
#  'isangel',
#  'rajapur',
#  'barcelos',
#  'severo-kurilsk',
#  'gilgit',
#  'khoy',
#  'amderma',
#  'half moon bay',
#  'gangotri',
#  'ostrovnoy',
#  'bowen',
#  'tatarbunary',
#  'nishihara',
#  'bonavista',
#  'jinchang',
#  'tornio',
#  'nome',
#  'waipawa',
#  'sepolno krajenskie',
#  'itarema',
#  'santa cruz',
#  'henties bay',
#  'asyut',
#  'methoni',
#  'santa isabel do rio negro',
#  'lata',
#  'benguela',
#  'bagdarin',
#  'volax',
#  'lakatoro',
#  'leticia',
#  'alugan',
#  'saint-augustin',
#  'bobo dioulasso',
#  'tshane',
#  'san pedro',
#  'portel',
#  'archidona',
#  'zaysan',
#  'boa vista',
#  'yacuiba',
#  'itaituba',
#  'bilma',
#  'djenne',
#  'sexsmith',
#  'hasaki',
#  'samalaeulu',
#  'alice springs',
#  'lieksa',
#  'san joaquin',
#  'lityn',
#  'san quintin',
#  'gat',
#  'great yarmouth',
#  'ranong',
#  'sitka',
#  'camabatela',
#  'thinadhoo',
#  'iqaluit',
#  'ilembula',
#  'luanda',
#  'dong xoai',
#  'bartica',
#  'meyungs',
#  'namibe',
#  'gorontalo',
#  'yumen',
#  'morro bay',
#  'humboldt',
#  'sri aman',
#  'qaqortoq',
#  'dharur',
#  'airai',
#  'bolshoye selo',
#  'balimo',
#  'codrington',
#  'brighouse',
#  'bulawayo',
#  'batagay-alyta',
#  'shingu',
#  'ugoofaaru',
#  'puerto escondido',
#  'avera',
#  'sao gabriel da cachoeira',
#  'dzaoudzi',
#  'auki',
#  'komsomolskiy',
#  'edson',
#  'port moresby',
#  'formoso do araguaia',
#  'tura',
#  'punta cardon',
#  'tena',
#  'kargasok',
#  'tawkar',
#  'el tambo',
#  'litovko',
#  'taburao',
#  'san luis',
#  'canutama',
#  'estelle',
#  'fairbanks',
#  'cracow',
#  'mangan',
#  'lasem',
#  'boden',
#  'tabuk',
#  'tilichiki',
#  'san lawrenz',
#  'matagami',
#  'alofi',
#  'delta del tigre',
#  'birao',
#  'nikel',
#  'asau',
#  'lagos',
#  'umzimvubu',
#  'bitung',
#  'aksarayskiy',
#  'sault sainte marie',
#  'uturoa',
#  'roald',
#  'dovolnoye',
#  'naryan-mar',
#  'galle',
#  'pointe michel',
#  'voh',
#  'rundu',
#  'kaura namoda',
#  'vanavara',
#  'kupang',
#  'bolungarvik',
#  'kandava',
#  'kamenka',
#  'antanifotsy',
#  'norton',
#  'lesnyye polyany',
#  'thunder bay',
#  'emerald',
#  'sembe',
#  'westpunt',
#  'nantucket',
#  'ulaangom',
#  'mocambique',
#  'kruisfontein',
#  'tumannyy',
#  'tulcingo',
#  'kodinsk',
#  'villarrica',
#  'colares',
#  'finote selam',
#  'cheuskiny',
#  'acarau',
#  'shambu',
#  'chabahar',
#  'mweka',
#  'mocuba',
#  'taltal',
#  'luau',
#  'balkhash',
#  'calvia',
#  'otane',
#  'phan rang',
#  'anloga',
#  'itigi',
#  'itoman',
#  'baruun-urt',
#  'obihiro',
#  'kurilsk',
#  'beira',
#  'merauke',
#  'kysyl-syr',
#  'taiobeiras',
#  'chernyshevskiy',
#  'dayong',
#  'ak-dovurak',
#  'shu',
#  'mandalgovi',
#  'guerrero negro',
#  'nandu',
#  'lipin bor',
#  'halalo',
#  'touros',
#  'banyo',
#  'atkinson',
#  'novobiryusinskiy',
#  'sokoni',
#  'hit',
#  'cao bang',
#  'mujiayingzi',
#  'plettenberg bay',
#  'kota bahru',
#  'bria',
#  'tiznit',
#  'celestun',
#  'rawson',
#  'san rafael del sur',
#  'trelew',
#  'hambantota',
#  'richards bay',
#  'yerbogachen',
#  'vila',
#  'muswellbrook',
#  'port augusta',
#  'temaraia',
#  'batangafo',
#  'dongsheng',
#  'whitehorse',
#  'la rioja',
#  'manicore',
#  'baiyin',
#  'neiafu',
#  'makakilo city',
#  'loudi',
#  'codajas',
#  'muravlenko',
#  'manta',
#  'portoferraio',
#  'aldan',
#  'ust-nera',
#  'manokwari',
#  'sydney',
#  'rio branco',
#  'twentynine palms',
#  'witu',
#  'wellington',
#  'stony plain',
#  'aguimes',
#  'dzhusaly',
#  'cap malheureux',
#  'monticello',
#  'kuche',
#  'washougal',
#  'eyl',
#  'bermeo',
#  'antsohihy',
#  'mapulot',
#  'namatanai',
#  'bandar penggaram',
#  'amberley',
#  'visby',
#  'nola',
#  'mehamn',
#  'calvinia',
#  'fukue',
#  'tezu',
#  'puro',
#  'saldanha',
#  'tigil',
#  'jiuquan',
#  'lolua',
#  'moyale',
#  'ballina',
#  'domoni',
#  'soe',
#  'saint-francois',
#  'bubaque',
#  'sao raimundo nonato',
#  'lumut',
#  'nha trang',
#  'palmer',
#  'mana',
#  'qadirpur ran',
#  'college',
#  'talara',
#  'iskateley',
#  'ucluelet',
#  'naron',
#  'lasa',
#  'lancaster',
#  'anadyr',
#  'arlit',
#  'santa fe',
#  'looc',
#  'elko',
#  'dudinka',
#  'bradford',
#  'pangkalanbuun',
#  'chicaman',
#  'callaway',
#  'oktyabrskiy',
#  'shar',
#  'nouakchott',
#  'samarai',
#  'poum',
#  'malabo',
#  'paamiut',
#  'fortuna',
#  'dauphin',
#  'hidalgo',
#  'killybegs',
#  'bousso',
#  'rupert',
#  'barawe',
#  'resistencia',
#  'panlaitan',
#  'severo-yeniseyskiy']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Creating URL for API calls
units = "imperial"
url = f"http://api.openweathermap.org/data/2.5/weather?appid={api_key}&units={units}&q="

# Creating lists to store API values
max_temp = []
humid = []
clouds = []
wind = []
lat = []
lon = []
city_name = []
country = []
date = []

# Creating counters to track number of cities and sets
city_counter = 0
set_counter = 1

# Printing beginning of data retrieval
print('Beginning Data Retrieval')
print('-'*30)

# For loop to make API calls
for city in cities:
    try:
        query_url = url + city.replace(" ", "&")
        
        response = requests.get(query_url).json()
        max_temp.append(response['main']['temp'])
        humid.append(response['main']['humidity'])
        clouds.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        city_name.append(response['name'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        if city_counter > 48:
            city_counter = 1
            set_counter += 1
        else:
            city_counter += 1
        print(f"Processing Record {city_counter} of {set_counter} | {city}")
    except KeyError:
        print('City not found. Skipping...')

print("-"*30 + "\nData Retrieval Complete\n" + "-"*30)
# Out:
# Beginning Data Retrieval
# ------------------------------
# City not found. Skipping...
# Processing Record 1 of 1 | grindavik
# Processing Record 2 of 1 | thompson
# Processing Record 3 of 1 | chuy
# Processing Record 4 of 1 | buala
# Processing Record 5 of 1 | nikolskoye
# Processing Record 6 of 1 | hobart
# Processing Record 7 of 1 | yulara
# City not found. Skipping...
# Processing Record 8 of 1 | manaus
# Processing Record 9 of 1 | svetlaya
# Processing Record 10 of 1 | tuktoyaktuk
# Processing Record 11 of 1 | kaitangata
# Processing Record 12 of 1 | ambilobe
# Processing Record 13 of 1 | busselton
# Processing Record 14 of 1 | albany
# Processing Record 15 of 1 | hermanus
# Processing Record 16 of 1 | teknaf
# Processing Record 17 of 1 | tottori
# Processing Record 18 of 1 | laguna
# Processing Record 19 of 1 | sorgun
# Processing Record 20 of 1 | cabo san lucas
# Processing Record 21 of 1 | haines junction
# Processing Record 22 of 1 | port hedland
# Processing Record 23 of 1 | leningradskiy
# Processing Record 24 of 1 | barrow
# Processing Record 25 of 1 | miranda
# Processing Record 26 of 1 | atuona
# Processing Record 27 of 1 | ushuaia
# Processing Record 28 of 1 | kapaa
# Processing Record 29 of 1 | longyearbyen
# City not found. Skipping...
# Processing Record 30 of 1 | upernavik
# Processing Record 31 of 1 | port alfred
# Processing Record 32 of 1 | puerto ayacucho
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 33 of 1 | starozhilovo
# Processing Record 34 of 1 | provideniya
# Processing Record 35 of 1 | okhotsk
# Processing Record 36 of 1 | grand river south east
# Processing Record 37 of 1 | punta arenas
# City not found. Skipping...
# Processing Record 38 of 1 | tuatapere
# Processing Record 39 of 1 | new norfolk
# Processing Record 40 of 1 | lompoc
# Processing Record 41 of 1 | kabare
# Processing Record 42 of 1 | constitucion
# Processing Record 43 of 1 | zhigansk
# Processing Record 44 of 1 | vaini
# Processing Record 45 of 1 | comodoro rivadavia
# City not found. Skipping...
# Processing Record 46 of 1 | ust-tsilma
# Processing Record 47 of 1 | genhe
# City not found. Skipping...
# Processing Record 48 of 1 | borovskoy
# City not found. Skipping...
# Processing Record 49 of 1 | yarke pole
# Processing Record 1 of 2 | astana
# Processing Record 2 of 2 | yellowknife
# Processing Record 3 of 2 | east london
# Processing Record 4 of 2 | myre
# Processing Record 5 of 2 | waitati
# Processing Record 6 of 2 | meulaboh
# City not found. Skipping...
# Processing Record 7 of 2 | tynda
# City not found. Skipping...
# Processing Record 8 of 2 | chokurdakh
# Processing Record 9 of 2 | bluff
# City not found. Skipping...
# Processing Record 10 of 2 | port elizabeth
# City not found. Skipping...
# Processing Record 11 of 2 | geraldton
# Processing Record 12 of 2 | narsaq
# Processing Record 13 of 2 | arraial do cabo
# Processing Record 14 of 2 | tessalit
# Processing Record 15 of 2 | butaritari
# Processing Record 16 of 2 | udankudi
# Processing Record 17 of 2 | cockburn town
# City not found. Skipping...
# Processing Record 18 of 2 | athabasca
# Processing Record 19 of 2 | carnarvon
# Processing Record 20 of 2 | rikitea
# Processing Record 21 of 2 | egvekinot
# Processing Record 22 of 2 | anchorage
# Processing Record 23 of 2 | caravelas
# Processing Record 24 of 2 | port blair
# Processing Record 25 of 2 | islahiye
# City not found. Skipping...
# Processing Record 26 of 2 | salalah
# Processing Record 27 of 2 | dhidhdhoo
# Processing Record 28 of 2 | tinskoy
# Processing Record 29 of 2 | nikki
# Processing Record 30 of 2 | belmonte
# Processing Record 31 of 2 | koutiala
# Processing Record 32 of 2 | port-gentil
# City not found. Skipping...
# Processing Record 33 of 2 | klaeng
# Processing Record 34 of 2 | hami
# Processing Record 35 of 2 | sao filipe
# Processing Record 36 of 2 | batticaloa
# Processing Record 37 of 2 | iranshahr
# Processing Record 38 of 2 | bambous virieux
# Processing Record 39 of 2 | san cristobal
# Processing Record 40 of 2 | bintulu
# Processing Record 41 of 2 | vestmannaeyjar
# Processing Record 42 of 2 | puerto ayora
# Processing Record 43 of 2 | labuhan
# City not found. Skipping...
# Processing Record 44 of 2 | najran
# Processing Record 45 of 2 | dikson
# Processing Record 46 of 2 | sao sebastiao
# Processing Record 47 of 2 | santa rosa de aguan
# City not found. Skipping...
# Processing Record 48 of 2 | avarua
# Processing Record 49 of 2 | qaanaaq
# Processing Record 1 of 3 | mataura
# Processing Record 2 of 3 | torbay
# Processing Record 3 of 3 | davila
# Processing Record 4 of 3 | khatanga
# Processing Record 5 of 3 | port lincoln
# City not found. Skipping...
# Processing Record 6 of 3 | bethel
# Processing Record 7 of 3 | mar del plata
# Processing Record 8 of 3 | ponta do sol
# Processing Record 9 of 3 | charters towers
# Processing Record 10 of 3 | jamestown
# Processing Record 11 of 3 | georgetown
# Processing Record 12 of 3 | castro
# Processing Record 13 of 3 | hilo
# Processing Record 14 of 3 | abu dhabi
# Processing Record 15 of 3 | bredasdorp
# Processing Record 16 of 3 | cape town
# Processing Record 17 of 3 | ilulissat
# Processing Record 18 of 3 | saskylakh
# City not found. Skipping...
# Processing Record 19 of 3 | sioux lookout
# Processing Record 20 of 3 | oranjemund
# Processing Record 21 of 3 | ongandjera
# Processing Record 22 of 3 | port hardy
# Processing Record 23 of 3 | ancud
# Processing Record 24 of 3 | madaoua
# Processing Record 25 of 3 | cherskiy
# Processing Record 26 of 3 | talnakh
# Processing Record 27 of 3 | blackford
# Processing Record 28 of 3 | soanierana ivongo
# City not found. Skipping...
# Processing Record 29 of 3 | coihaique
# Processing Record 30 of 3 | maniitsoq
# Processing Record 31 of 3 | houma
# Processing Record 32 of 3 | puerto suarez
# Processing Record 33 of 3 | sinnamary
# Processing Record 34 of 3 | kodiak
# Processing Record 35 of 3 | khyriv
# Processing Record 36 of 3 | sulangan
# Processing Record 37 of 3 | tiksi
# Processing Record 38 of 3 | dutlwe
# Processing Record 39 of 3 | faanui
# Processing Record 40 of 3 | inirida
# Processing Record 41 of 3 | tautira
# City not found. Skipping...
# Processing Record 42 of 3 | mahebourg
# City not found. Skipping...
# Processing Record 43 of 3 | tasiilaq
# Processing Record 44 of 3 | ahipara
# Processing Record 45 of 3 | erzin
# Processing Record 46 of 3 | algiers
# Processing Record 47 of 3 | sosnovo-ozerskoye
# Processing Record 48 of 3 | baker city
# Processing Record 49 of 3 | cam ranh
# Processing Record 1 of 4 | novopokrovka
# Processing Record 2 of 4 | vao
# City not found. Skipping...
# Processing Record 3 of 4 | pahrump
# City not found. Skipping...
# Processing Record 4 of 4 | hithadhoo
# City not found. Skipping...
# Processing Record 5 of 4 | mys shmidta
# Processing Record 6 of 4 | noumea
# Processing Record 7 of 4 | husavik
# Processing Record 8 of 4 | poya
# Processing Record 9 of 4 | kawalu
# Processing Record 10 of 4 | hualmay
# Processing Record 11 of 4 | dongying
# Processing Record 12 of 4 | havoysund
# Processing Record 13 of 4 | pisco
# Processing Record 14 of 4 | upornaya
# Processing Record 15 of 4 | magdeburg
# City not found. Skipping...
# Processing Record 16 of 4 | nanortalik
# Processing Record 17 of 4 | puri
# Processing Record 18 of 4 | ngunguru
# Processing Record 19 of 4 | lebu
# Processing Record 20 of 4 | lagoa
# Processing Record 21 of 4 | tiarei
# Processing Record 22 of 4 | esperance
# City not found. Skipping...
# Processing Record 23 of 4 | pevek
# Processing Record 24 of 4 | katsuura
# Processing Record 25 of 4 | cayenne
# City not found. Skipping...
# Processing Record 26 of 4 | kahului
# Processing Record 27 of 4 | shenjiamen
# Processing Record 28 of 4 | miandrivazo
# Processing Record 29 of 4 | camoapa
# City not found. Skipping...
# Processing Record 30 of 4 | heishan
# Processing Record 31 of 4 | norman wells
# City not found. Skipping...
# Processing Record 32 of 4 | cidreira
# City not found. Skipping...
# Processing Record 33 of 4 | hofn
# Processing Record 34 of 4 | vila velha
# Processing Record 35 of 4 | dingle
# Processing Record 36 of 4 | coquimbo
# Processing Record 37 of 4 | yarada
# Processing Record 38 of 4 | gold coast
# Processing Record 39 of 4 | gamba
# Processing Record 40 of 4 | jumla
# Processing Record 41 of 4 | acapulco
# Processing Record 42 of 4 | atar
# Processing Record 43 of 4 | mahibadhoo
# Processing Record 44 of 4 | port macquarie
# Processing Record 45 of 4 | glendive
# Processing Record 46 of 4 | wapi pathum
# Processing Record 47 of 4 | sept-iles
# Processing Record 48 of 4 | dalbandin
# City not found. Skipping...
# Processing Record 49 of 4 | pangnirtung
# Processing Record 1 of 5 | saint-joseph
# Processing Record 2 of 5 | abha
# Processing Record 3 of 5 | saint-philippe
# Processing Record 4 of 5 | lisakovsk
# Processing Record 5 of 5 | vila franca do campo
# Processing Record 6 of 5 | vincennes
# Processing Record 7 of 5 | dwarka
# Processing Record 8 of 5 | victoria
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 9 of 5 | hovd
# Processing Record 10 of 5 | takoradi
# Processing Record 11 of 5 | xinqing
# Processing Record 12 of 5 | suluq
# Processing Record 13 of 5 | sistranda
# Processing Record 14 of 5 | vanimo
# Processing Record 15 of 5 | maralal
# Processing Record 16 of 5 | brae
# Processing Record 17 of 5 | tondano
# Processing Record 18 of 5 | beloha
# Processing Record 19 of 5 | tutoia
# Processing Record 20 of 5 | sangar
# Processing Record 21 of 5 | chicama
# Processing Record 22 of 5 | karratha
# Processing Record 23 of 5 | eenhana
# City not found. Skipping...
# Processing Record 24 of 5 | matay
# Processing Record 25 of 5 | sao miguel do araguaia
# Processing Record 26 of 5 | puerto del rosario
# Processing Record 27 of 5 | ambon
# Processing Record 28 of 5 | likasi
# Processing Record 29 of 5 | cururupu
# Processing Record 30 of 5 | luderitz
# Processing Record 31 of 5 | toamasina
# City not found. Skipping...
# Processing Record 32 of 5 | inongo
# Processing Record 33 of 5 | arman
# Processing Record 34 of 5 | hamilton
# Processing Record 35 of 5 | santa rosa
# City not found. Skipping...
# Processing Record 36 of 5 | berlevag
# Processing Record 37 of 5 | myitkyina
# Processing Record 38 of 5 | shwebo
# Processing Record 39 of 5 | nelson bay
# City not found. Skipping...
# Processing Record 40 of 5 | kamaishi
# Processing Record 41 of 5 | matara
# Processing Record 42 of 5 | deputatskiy
# Processing Record 43 of 5 | aykino
# Processing Record 44 of 5 | hazorasp
# Processing Record 45 of 5 | upata
# Processing Record 46 of 5 | moscow
# Processing Record 47 of 5 | pimentel
# City not found. Skipping...
# Processing Record 48 of 5 | lavrentiya
# Processing Record 49 of 5 | naze
# Processing Record 1 of 6 | ribeira grande
# Processing Record 2 of 6 | raudeberg
# Processing Record 3 of 6 | derzhavinsk
# Processing Record 4 of 6 | usinsk
# Processing Record 5 of 6 | goure
# City not found. Skipping...
# Processing Record 6 of 6 | zaraza
# Processing Record 7 of 6 | mount isa
# Processing Record 8 of 6 | ketchikan
# Processing Record 9 of 6 | koroni
# Processing Record 10 of 6 | praia da vitoria
# Processing Record 11 of 6 | qasigiannguit
# Processing Record 12 of 6 | neftcala
# Processing Record 13 of 6 | lorengau
# Processing Record 14 of 6 | sampit
# Processing Record 15 of 6 | bathsheba
# City not found. Skipping...
# Processing Record 16 of 6 | porto novo
# Processing Record 17 of 6 | ebolowa
# Processing Record 18 of 6 | moose factory
# Processing Record 19 of 6 | kavieng
# Processing Record 20 of 6 | semey
# Processing Record 21 of 6 | kirakira
# Processing Record 22 of 6 | warrington
# Processing Record 23 of 6 | atbasar
# City not found. Skipping...
# Processing Record 24 of 6 | bundaberg
# Processing Record 25 of 6 | gulf gate estates
# Processing Record 26 of 6 | isangel
# Processing Record 27 of 6 | rajapur
# Processing Record 28 of 6 | barcelos
# Processing Record 29 of 6 | severo-kurilsk
# Processing Record 30 of 6 | gilgit
# Processing Record 31 of 6 | khoy
# City not found. Skipping...
# Processing Record 32 of 6 | half moon bay
# City not found. Skipping...
# Processing Record 33 of 6 | ostrovnoy
# Processing Record 34 of 6 | bowen
# Processing Record 35 of 6 | tatarbunary
# Processing Record 36 of 6 | nishihara
# Processing Record 37 of 6 | bonavista
# Processing Record 38 of 6 | jinchang
# Processing Record 39 of 6 | tornio
# Processing Record 40 of 6 | nome
# Processing Record 41 of 6 | waipawa
# City not found. Skipping...
# Processing Record 42 of 6 | itarema
# Processing Record 43 of 6 | santa cruz
# City not found. Skipping...
# Processing Record 44 of 6 | asyut
# Processing Record 45 of 6 | methoni
# Processing Record 46 of 6 | santa isabel do rio negro
# Processing Record 47 of 6 | lata
# Processing Record 48 of 6 | benguela
# Processing Record 49 of 6 | bagdarin
# Processing Record 1 of 7 | volax
# Processing Record 2 of 7 | lakatoro
# Processing Record 3 of 7 | leticia
# Processing Record 4 of 7 | alugan
# Processing Record 5 of 7 | saint-augustin
# Processing Record 6 of 7 | bobo dioulasso
# Processing Record 7 of 7 | tshane
# Processing Record 8 of 7 | san pedro
# Processing Record 9 of 7 | portel
# Processing Record 10 of 7 | archidona
# Processing Record 11 of 7 | zaysan
# Processing Record 12 of 7 | boa vista
# Processing Record 13 of 7 | yacuiba
# Processing Record 14 of 7 | itaituba
# Processing Record 15 of 7 | bilma
# Processing Record 16 of 7 | djenne
# Processing Record 17 of 7 | sexsmith
# Processing Record 18 of 7 | hasaki
# City not found. Skipping...
# Processing Record 19 of 7 | alice springs
# Processing Record 20 of 7 | lieksa
# Processing Record 21 of 7 | san joaquin
# Processing Record 22 of 7 | lityn
# Processing Record 23 of 7 | san quintin
# Processing Record 24 of 7 | gat
# City not found. Skipping...
# Processing Record 25 of 7 | ranong
# Processing Record 26 of 7 | sitka
# Processing Record 27 of 7 | camabatela
# Processing Record 28 of 7 | thinadhoo
# Processing Record 29 of 7 | iqaluit
# Processing Record 30 of 7 | ilembula
# Processing Record 31 of 7 | luanda
# Processing Record 32 of 7 | dong xoai
# Processing Record 33 of 7 | bartica
# City not found. Skipping...
# Processing Record 34 of 7 | namibe
# Processing Record 35 of 7 | gorontalo
# Processing Record 36 of 7 | yumen
# Processing Record 37 of 7 | morro bay
# Processing Record 38 of 7 | humboldt
# Processing Record 39 of 7 | sri aman
# Processing Record 40 of 7 | qaqortoq
# Processing Record 41 of 7 | dharur
# Processing Record 42 of 7 | airai
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 43 of 7 | codrington
# Processing Record 44 of 7 | brighouse
# Processing Record 45 of 7 | bulawayo
# Processing Record 46 of 7 | batagay-alyta
# Processing Record 47 of 7 | shingu
# Processing Record 48 of 7 | ugoofaaru
# Processing Record 49 of 7 | puerto escondido
# Processing Record 1 of 8 | avera
# Processing Record 2 of 8 | sao gabriel da cachoeira
# Processing Record 3 of 8 | dzaoudzi
# Processing Record 4 of 8 | auki
# Processing Record 5 of 8 | komsomolskiy
# Processing Record 6 of 8 | edson
# Processing Record 7 of 8 | port moresby
# Processing Record 8 of 8 | formoso do araguaia
# Processing Record 9 of 8 | tura
# Processing Record 10 of 8 | punta cardon
# Processing Record 11 of 8 | tena
# Processing Record 12 of 8 | kargasok
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 13 of 8 | litovko
# City not found. Skipping...
# Processing Record 14 of 8 | san luis
# Processing Record 15 of 8 | canutama
# Processing Record 16 of 8 | estelle
# Processing Record 17 of 8 | fairbanks
# Processing Record 18 of 8 | cracow
# Processing Record 19 of 8 | mangan
# Processing Record 20 of 8 | lasem
# Processing Record 21 of 8 | boden
# Processing Record 22 of 8 | tabuk
# Processing Record 23 of 8 | tilichiki
# Processing Record 24 of 8 | san lawrenz
# Processing Record 25 of 8 | matagami
# Processing Record 26 of 8 | alofi
# Processing Record 27 of 8 | delta del tigre
# Processing Record 28 of 8 | birao
# Processing Record 29 of 8 | nikel
# City not found. Skipping...
# Processing Record 30 of 8 | lagos
# City not found. Skipping...
# Processing Record 31 of 8 | bitung
# Processing Record 32 of 8 | aksarayskiy
# Processing Record 33 of 8 | sault sainte marie
# Processing Record 34 of 8 | uturoa
# Processing Record 35 of 8 | roald
# Processing Record 36 of 8 | dovolnoye
# Processing Record 37 of 8 | naryan-mar
# Processing Record 38 of 8 | galle
# City not found. Skipping...
# Processing Record 39 of 8 | voh
# Processing Record 40 of 8 | rundu
# Processing Record 41 of 8 | kaura namoda
# Processing Record 42 of 8 | vanavara
# Processing Record 43 of 8 | kupang
# City not found. Skipping...
# Processing Record 44 of 8 | kandava
# Processing Record 45 of 8 | kamenka
# Processing Record 46 of 8 | antanifotsy
# Processing Record 47 of 8 | norton
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 48 of 8 | emerald
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 49 of 8 | nantucket
# Processing Record 1 of 9 | ulaangom
# City not found. Skipping...
# Processing Record 2 of 9 | kruisfontein
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 3 of 9 | kodinsk
# Processing Record 4 of 9 | villarrica
# Processing Record 5 of 9 | colares
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 6 of 9 | shambu
# Processing Record 7 of 9 | chabahar
# Processing Record 8 of 9 | mweka
# Processing Record 9 of 9 | mocuba
# Processing Record 10 of 9 | taltal
# Processing Record 11 of 9 | luau
# Processing Record 12 of 9 | balkhash
# Processing Record 13 of 9 | calvia
# Processing Record 14 of 9 | otane
# Processing Record 15 of 9 | phan rang
# Processing Record 16 of 9 | anloga
# Processing Record 17 of 9 | itigi
# Processing Record 18 of 9 | itoman
# Processing Record 19 of 9 | baruun-urt
# Processing Record 20 of 9 | obihiro
# Processing Record 21 of 9 | kurilsk
# Processing Record 22 of 9 | beira
# Processing Record 23 of 9 | merauke
# Processing Record 24 of 9 | kysyl-syr
# Processing Record 25 of 9 | taiobeiras
# Processing Record 26 of 9 | chernyshevskiy
# Processing Record 27 of 9 | dayong
# Processing Record 28 of 9 | ak-dovurak
# Processing Record 29 of 9 | shu
# Processing Record 30 of 9 | mandalgovi
# Processing Record 31 of 9 | guerrero negro
# Processing Record 32 of 9 | nandu
# Processing Record 33 of 9 | lipin bor
# City not found. Skipping...
# Processing Record 34 of 9 | touros
# Processing Record 35 of 9 | banyo
# Processing Record 36 of 9 | atkinson
# Processing Record 37 of 9 | novobiryusinskiy
# Processing Record 38 of 9 | sokoni
# Processing Record 39 of 9 | hit
# Processing Record 40 of 9 | cao bang
# Processing Record 41 of 9 | mujiayingzi
# Processing Record 42 of 9 | plettenberg bay
# Processing Record 43 of 9 | kota bahru
# Processing Record 44 of 9 | bria
# Processing Record 45 of 9 | tiznit
# Processing Record 46 of 9 | celestun
# Processing Record 47 of 9 | rawson
# Processing Record 48 of 9 | san rafael del sur
# Processing Record 49 of 9 | trelew
# Processing Record 1 of 10 | hambantota
# Processing Record 2 of 10 | richards bay
# Processing Record 3 of 10 | yerbogachen
# Processing Record 4 of 10 | vila
# Processing Record 5 of 10 | muswellbrook
# Processing Record 6 of 10 | port augusta
# City not found. Skipping...
# Processing Record 7 of 10 | batangafo
# Processing Record 8 of 10 | dongsheng
# Processing Record 9 of 10 | whitehorse
# City not found. Skipping...
# Processing Record 10 of 10 | manicore
# Processing Record 11 of 10 | baiyin
# Processing Record 12 of 10 | neiafu
# Processing Record 13 of 10 | makakilo city
# Processing Record 14 of 10 | loudi
# Processing Record 15 of 10 | codajas
# Processing Record 16 of 10 | muravlenko
# Processing Record 17 of 10 | manta
# Processing Record 18 of 10 | portoferraio
# Processing Record 19 of 10 | aldan
# Processing Record 20 of 10 | ust-nera
# Processing Record 21 of 10 | manokwari
# Processing Record 22 of 10 | sydney
# Processing Record 23 of 10 | rio branco
# City not found. Skipping...
# Processing Record 24 of 10 | witu
# Processing Record 25 of 10 | wellington
# Processing Record 26 of 10 | stony plain
# Processing Record 27 of 10 | aguimes
# City not found. Skipping...
# Processing Record 28 of 10 | cap malheureux
# Processing Record 29 of 10 | monticello
# City not found. Skipping...
# Processing Record 30 of 10 | washougal
# Processing Record 31 of 10 | eyl
# Processing Record 32 of 10 | bermeo
# Processing Record 33 of 10 | antsohihy
# Processing Record 34 of 10 | mapulot
# Processing Record 35 of 10 | namatanai
# Processing Record 36 of 10 | bandar penggaram
# Processing Record 37 of 10 | amberley
# Processing Record 38 of 10 | visby
# Processing Record 39 of 10 | nola
# Processing Record 40 of 10 | mehamn
# Processing Record 41 of 10 | calvinia
# Processing Record 42 of 10 | fukue
# Processing Record 43 of 10 | tezu
# Processing Record 44 of 10 | puro
# Processing Record 45 of 10 | saldanha
# Processing Record 46 of 10 | tigil
# Processing Record 47 of 10 | jiuquan
# City not found. Skipping...
# Processing Record 48 of 10 | moyale
# Processing Record 49 of 10 | ballina
# City not found. Skipping...
# Processing Record 1 of 11 | soe
# Processing Record 2 of 11 | saint-francois
# Processing Record 3 of 11 | bubaque
# Processing Record 4 of 11 | sao raimundo nonato
# Processing Record 5 of 11 | lumut
# Processing Record 6 of 11 | nha trang
# Processing Record 7 of 11 | palmer
# Processing Record 8 of 11 | mana
# Processing Record 9 of 11 | qadirpur ran
# Processing Record 10 of 11 | college
# Processing Record 11 of 11 | talara
# Processing Record 12 of 11 | iskateley
# Processing Record 13 of 11 | ucluelet
# Processing Record 14 of 11 | naron
# Processing Record 15 of 11 | lasa
# Processing Record 16 of 11 | lancaster
# Processing Record 17 of 11 | anadyr
# Processing Record 18 of 11 | arlit
# Processing Record 19 of 11 | santa fe
# Processing Record 20 of 11 | looc
# Processing Record 21 of 11 | elko
# Processing Record 22 of 11 | dudinka
# Processing Record 23 of 11 | bradford
# Processing Record 24 of 11 | pangkalanbuun
# Processing Record 25 of 11 | chicaman
# Processing Record 26 of 11 | callaway
# Processing Record 27 of 11 | oktyabrskiy
# Processing Record 28 of 11 | shar
# Processing Record 29 of 11 | nouakchott
# Processing Record 30 of 11 | samarai
# Processing Record 31 of 11 | poum
# Processing Record 32 of 11 | malabo
# Processing Record 33 of 11 | paamiut
# Processing Record 34 of 11 | fortuna
# Processing Record 35 of 11 | dauphin
# Processing Record 36 of 11 | hidalgo
# Processing Record 37 of 11 | killybegs
# City not found. Skipping...
# Processing Record 38 of 11 | rupert
# City not found. Skipping...
# Processing Record 39 of 11 | resistencia
# Processing Record 40 of 11 | panlaitan
# Processing Record 41 of 11 | severo-yeniseyskiy
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
print('-'*30)
